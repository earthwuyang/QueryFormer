# %%
import pandas as pd
import json
import re
import math
import numpy as np
from collections import defaultdict
import psycopg2
import time
import os

# %%
imdb_schema = {'title': ['t.id', 't.kind_id', 't.production_year'],
 'movie_companies': ['mc.id',
  'mc.company_id',
  'mc.movie_id',
  'mc.company_type_id'],
 'cast_info': ['ci.id', 'ci.movie_id', 'ci.person_id', 'ci.role_id'],
 'movie_info_idx': ['mi_idx.id', 'mi_idx.movie_id', 'mi_idx.info_type_id'],
 'movie_info': ['mi.id', 'mi.movie_id', 'mi.info_type_id'],
 'movie_keyword': ['mk.id', 'mk.movie_id', 'mk.keyword_id']}
t2alias = {'title':'t','movie_companies':'mc','cast_info':'ci',
          'movie_info_idx':'mi_idx','movie_info':'mi','movie_keyword':'mk'}
alias2t = {}
for k,v in t2alias.items(): alias2t[v] = k

# %%
conm = psycopg2.connect(database="imdb", user="wuy", host="127.0.0.1",password="wuy", port="5432")
conm.set_session(autocommit=True)
cur = conm.cursor()

# %%
def to_vals(data_list):
    '''
    convert a list of tuples to a numpy array of values
    '''
    for dat in data_list:
        val = dat[0]
        # finds first non-None value
        if val is not None: break 
    try:
        float(val)
        return np.array(data_list, dtype=float).squeeze()
    except:
#         print(val)
        res = []
        for dat in data_list:
            try:
                mi = dat[0].timestamp()
            except:
                mi = 0
            res.append(mi)
        return np.array(res)

# %% [markdown]
# ## Histogram

# %%
hist_file_path ='data/imdb/new_hist_file.csv'
if os.path.exists(hist_file_path):
    hist_file = pd.read_csv(hist_file_path)
else:
    hist_file = pd.DataFrame(columns=['table','column','bins','table_column'])
    hist_file
    for table,columns in imdb_schema.items():
        for column in columns:
            cmd = 'select {} from {} as {}'.format(column, table,t2alias[table])
            cur.execute(cmd)
            col = cur.fetchall()
            col_array = to_vals(col)
            # calculate the percentile of the col_array, at intervals of 2%, forming the basis for the histogram bins.
            hists = np.nanpercentile(col_array, range(0,101,2), axis=0)
            res_dict = {
                'table':table,
                'column':column,
                'table_column': '.'.join((table, column)),
                'bins':hists
            }
            # hist_file = hist_file.append(res_dict,ignore_index=True)
            hist_file = pd.concat([hist_file, pd.DataFrame(res_dict)], ignore_index=True)
            hist_file.to_csv(hist_file_path, index=False)

# %%
hist_file
# Out:
#               table         column       bins                 table_column
# 0             title           t.id       1.00                   title.t.id
# 1             title           t.id   50567.22                   title.t.id
# 2             title           t.id  101133.44                   title.t.id
# 3             title           t.id  151699.66                   title.t.id
# 4             title           t.id  202265.88                   title.t.id
# ...             ...            ...        ...                          ...
# 1015  movie_keyword  mk.keyword_id   46138.00  movie_keyword.mk.keyword_id
# 1016  movie_keyword  mk.keyword_id   58101.00  movie_keyword.mk.keyword_id
# 1017  movie_keyword  mk.keyword_id   71628.84  movie_keyword.mk.keyword_id
# 1018  movie_keyword  mk.keyword_id   84788.00  movie_keyword.mk.keyword_id
# 1019  movie_keyword  mk.keyword_id  134170.00  movie_keyword.mk.keyword_id
#
# [1020 rows x 4 columns]

# %% [markdown]
# ## Simpler Approach to sample without creating a smaller database

# %%
import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine
import os
import logging
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s:%(message)s')

NUM_SAMPLES_PER_TABLE = 1000  # Adjust as needed

def sample_table(cursor, table, alias, num_samples):
    """
    Samples a specified number of rows from a table using TABLESAMPLE SYSTEM_ROWS.

    Args:
        cursor: psycopg2 cursor object.
        table (str): Table name.
        alias (str): Alias for the table.
        num_samples (int): Number of samples to fetch.

    Returns:
        pd.DataFrame: Sampled data as a DataFrame.
    """
    try:
        # Calculate the sampling rate to approximate the desired number of samples
        # Note: SYSTEM_ROWS may not guarantee exact sample size; adjust as needed
        sampling_cmd = f"SELECT * FROM {table} AS {alias} TABLESAMPLE SYSTEM_ROWS({num_samples}) "
        cursor.execute(sampling_cmd)
        samples = cursor.fetchall()
        colnames = [desc[0] for desc in cursor.description]
        df = pd.DataFrame(samples, columns=colnames)
        logging.info(f"Sampled {len(df)} rows from table '{table}'.")
        return df
    except Exception as e:
        logging.error(f"Error sampling table '{table}': {e}")
        return pd.DataFrame()  # Return empty DataFrame on error

# Dictionary to hold sampled data
sampled_data = {}

for table, columns in imdb_schema.items():
    alias = t2alias[table]
    df = sample_table(cur, table, alias, NUM_SAMPLES_PER_TABLE)
    if not df.empty:
        # Assign a unique sample ID
        df['sid'] = range(len(df))
        sampled_data[table] = df
# Out:
# 2024-10-18 19:53:41,203 INFO:Sampled 1000 rows from table 'title'.
# 2024-10-18 19:53:41,208 INFO:Sampled 1000 rows from table 'movie_companies'.
# 2024-10-18 19:53:41,213 INFO:Sampled 1000 rows from table 'cast_info'.
# 2024-10-18 19:53:41,217 INFO:Sampled 1000 rows from table 'movie_info_idx'.
# 2024-10-18 19:53:41,221 INFO:Sampled 1000 rows from table 'movie_info'.
# 2024-10-18 19:53:41,225 INFO:Sampled 1000 rows from table 'movie_keyword'.

# %%
# Path to the synthetic workload file
synthetic_workload_path = 'data/imdb/workloads/synthetic.csv'

# Check if the file exists
if not os.path.exists(synthetic_workload_path):
    logging.error(f"Synthetic workload file not found at '{synthetic_workload_path}'.")
    raise FileNotFoundError(f"Synthetic workload file not found at '{synthetic_workload_path}'.")

# Read the synthetic workload CSV
query_file = pd.read_csv(synthetic_workload_path, sep='#', header=None)
query_file.columns = ['table', 'join', 'predicate', 'card']
logging.info("Loaded synthetic workload queries.")
# Out:
# 2024-10-18 19:54:01,452 INFO:Loaded synthetic workload queries.

# %%
def apply_predicates(sampled_data, predicates):
    """
    Applies a list of predicates to the sampled data and returns bitmaps.

    Args:
        sampled_data (dict): Dictionary of sampled DataFrames per table.
        predicates (list): List of predicates in triplet form [left, op, right].

    Returns:
        dict: Dictionary of bitmaps per table.
    """
    table_bitmaps = {}
    for i in range(0, len(predicates), 3):
        left, op, right = predicates[i:i+3]
        alias, col = left.split('.')
        table = alias2t.get(alias)
        if not table:
            logging.warning(f"Alias '{alias}' not found in alias2t mapping.")
            continue
        df = sampled_data.get(table)
        if df is None:
            logging.warning(f"No sampled data found for table '{table}'.")
            continue
        
        # Convert right to appropriate type
        # This example assumes integer comparisons; adjust as needed
        try:
            right_val = int(right)
        except ValueError:
            try:
                right_val = float(right)
            except ValueError:
                # Assume string if not numeric
                right_val = right.strip("'")  # Remove quotes if any
        
        # Build the query string dynamically
        if op in ['=', '==']:
            condition = df[col] == right_val
        elif op == '>':
            condition = df[col] > right_val
        elif op == '<':
            condition = df[col] < right_val
        elif op == '>=':
            condition = df[col] >= right_val
        elif op == '<=':
            condition = df[col] <= right_val
        elif op == '!=':
            condition = df[col] != right_val
        else:
            logging.warning(f"Unsupported operator '{op}' in predicate.")
            continue
        
        # Generate bitmap
        bitmap = condition.astype('uint8').values  # 1 for True, 0 for False
        if table in table_bitmaps:
            table_bitmaps[table] &= bitmap  # Combine with existing bitmap
        else:
            table_bitmaps[table] = bitmap
    return table_bitmaps

# %%
# List to hold bitmap results for each query
table_samples = []

for idx, row in query_file.iterrows():
    predicates = row['predicate'].split(',')
    bitmaps = apply_predicates(sampled_data, predicates)
    table_samples.append(bitmaps)
    logging.info(f"Processed query {idx}: Generated bitmaps.")

logging.info("Completed processing all synthetic workload queries.")
# Out:
# 2024-10-18 19:59:18,652 INFO:Processed query 0: Generated bitmaps.
# 2024-10-18 19:59:18,656 INFO:Processed query 1: Generated bitmaps.
# 2024-10-18 19:59:18,657 INFO:Processed query 2: Generated bitmaps.
# 2024-10-18 19:59:18,658 INFO:Processed query 3: Generated bitmaps.
# 2024-10-18 19:59:18,660 INFO:Processed query 4: Generated bitmaps.
# 2024-10-18 19:59:18,662 INFO:Processed query 5: Generated bitmaps.
# 2024-10-18 19:59:18,664 INFO:Processed query 6: Generated bitmaps.
# 2024-10-18 19:59:18,666 INFO:Processed query 7: Generated bitmaps.
# 2024-10-18 19:59:18,668 INFO:Processed query 8: Generated bitmaps.
# 2024-10-18 19:59:18,670 INFO:Processed query 9: Generated bitmaps.
# 2024-10-18 19:59:18,671 INFO:Processed query 10: Generated bitmaps.
# 2024-10-18 19:59:18,673 INFO:Processed query 11: Generated bitmaps.
# 2024-10-18 19:59:18,674 INFO:Processed query 12: Generated bitmaps.
# 2024-10-18 19:59:18,678 INFO:Processed query 13: Generated bitmaps.
# 2024-10-18 19:59:18,681 INFO:Processed query 14: Generated bitmaps.
# 2024-10-18 19:59:18,683 INFO:Processed query 15: Generated bitmaps.
# 2024-10-18 19:59:18,686 INFO:Processed query 16: Generated bitmaps.
# 2024-10-18 19:59:18,687 INFO:Processed query 17: Generated bitmaps.
# 2024-10-18 19:59:18,691 INFO:Processed query 18: Generated bitmaps.
# 2024-10-18 19:59:18,694 INFO:Processed query 19: Generated bitmaps.
# 2024-10-18 19:59:18,695 INFO:Processed query 20: Generated bitmaps.
# 2024-10-18 19:59:18,697 INFO:Processed query 21: Generated bitmaps.
# 2024-10-18 19:59:18,700 INFO:Processed query 22: Generated bitmaps.
# 2024-10-18 19:59:18,702 INFO:Processed query 23: Generated bitmaps.
# 2024-10-18 19:59:18,704 INFO:Processed query 24: Generated bitmaps.
# 2024-10-18 19:59:18,708 INFO:Processed query 25: Generated bitmaps.
# 2024-10-18 19:59:18,710 INFO:Processed query 26: Generated bitmaps.
# 2024-10-18 19:59:18,712 INFO:Processed query 27: Generated bitmaps.
# 2024-10-18 19:59:18,714 INFO:Processed query 28: Generated bitmaps.
# 2024-10-18 19:59:18,716 INFO:Processed query 29: Generated bitmaps.
# 2024-10-18 19:59:18,718 INFO:Processed query 30: Generated bitmaps.
# 2024-10-18 19:59:18,720 INFO:Processed query 31: Generated bitmaps.
# 2024-10-18 19:59:18,722 INFO:Processed query 32: Generated bitmaps.
# 2024-10-18 19:59:18,723 INFO:Processed query 33: Generated bitmaps.
# 2024-10-18 19:59:18,725 INFO:Processed query 34: Generated bitmaps.
# 2024-10-18 19:59:18,726 INFO:Processed query 35: Generated bitmaps.
# 2024-10-18 19:59:18,728 INFO:Processed query 36: Generated bitmaps.
# 2024-10-18 19:59:18,729 INFO:Processed query 37: Generated bitmaps.
# 2024-10-18 19:59:18,731 INFO:Processed query 38: Generated bitmaps.
# 2024-10-18 19:59:18,732 INFO:Processed query 39: Generated bitmaps.
# 2024-10-18 19:59:18,733 INFO:Processed query 40: Generated bitmaps.
# 2024-10-18 19:59:18,736 INFO:Processed query 41: Generated bitmaps.
# 2024-10-18 19:59:18,737 INFO:Processed query 42: Generated bitmaps.
# 2024-10-18 19:59:18,739 INFO:Processed query 43: Generated bitmaps.
# 2024-10-18 19:59:18,740 INFO:Processed query 44: Generated bitmaps.
# 2024-10-18 19:59:18,741 INFO:Processed query 45: Generated bitmaps.
# 2024-10-18 19:59:18,743 INFO:Processed query 46: Generated bitmaps.
# 2024-10-18 19:59:18,744 INFO:Processed query 47: Generated bitmaps.
# 2024-10-18 19:59:18,745 INFO:Processed query 48: Generated bitmaps.
# 2024-10-18 19:59:18,747 INFO:Processed query 49: Generated bitmaps.
# 2024-10-18 19:59:18,748 INFO:Processed query 50: Generated bitmaps.
# 2024-10-18 19:59:18,749 INFO:Processed query 51: Generated bitmaps.
# 2024-10-18 19:59:18,750 INFO:Processed query 52: Generated bitmaps.
# 2024-10-18 19:59:18,751 INFO:Processed query 53: Generated bitmaps.
# 2024-10-18 19:59:18,752 INFO:Processed query 54: Generated bitmaps.
# 2024-10-18 19:59:18,754 INFO:Processed query 55: Generated bitmaps.
# 2024-10-18 19:59:18,755 INFO:Processed query 56: Generated bitmaps.
# 2024-10-18 19:59:18,755 INFO:Processed query 57: Generated bitmaps.
# 2024-10-18 19:59:18,757 INFO:Processed query 58: Generated bitmaps.
# 2024-10-18 19:59:18,757 INFO:Processed query 59: Generated bitmaps.
# 2024-10-18 19:59:18,758 INFO:Processed query 60: Generated bitmaps.
# 2024-10-18 19:59:18,759 INFO:Processed query 61: Generated bitmaps.
# 2024-10-18 19:59:18,760 INFO:Processed query 62: Generated bitmaps.
# 2024-10-18 19:59:18,761 INFO:Processed query 63: Generated bitmaps.
# 2024-10-18 19:59:18,762 INFO:Processed query 64: Generated bitmaps.
# 2024-10-18 19:59:18,763 INFO:Processed query 65: Generated bitmaps.
# 2024-10-18 19:59:18,764 INFO:Processed query 66: Generated bitmaps.
# 2024-10-18 19:59:18,765 INFO:Processed query 67: Generated bitmaps.
# 2024-10-18 19:59:18,766 INFO:Processed query 68: Generated bitmaps.
# 2024-10-18 19:59:18,767 INFO:Processed query 69: Generated bitmaps.
# 2024-10-18 19:59:18,768 INFO:Processed query 70: Generated bitmaps.
# 2024-10-18 19:59:18,769 INFO:Processed query 71: Generated bitmaps.
# 2024-10-18 19:59:18,770 INFO:Processed query 72: Generated bitmaps.
# 2024-10-18 19:59:18,770 INFO:Processed query 73: Generated bitmaps.
# 2024-10-18 19:59:18,771 INFO:Processed query 74: Generated bitmaps.
# 2024-10-18 19:59:18,772 INFO:Processed query 75: Generated bitmaps.
# 2024-10-18 19:59:18,773 INFO:Processed query 76: Generated bitmaps.
# 2024-10-18 19:59:18,774 INFO:Processed query 77: Generated bitmaps.
# 2024-10-18 19:59:18,775 INFO:Processed query 78: Generated bitmaps.
# 2024-10-18 19:59:18,776 INFO:Processed query 79: Generated bitmaps.
# 2024-10-18 19:59:18,777 INFO:Processed query 80: Generated bitmaps.
# 2024-10-18 19:59:18,778 INFO:Processed query 81: Generated bitmaps.
# 2024-10-18 19:59:18,779 INFO:Processed query 82: Generated bitmaps.
# 2024-10-18 19:59:18,780 INFO:Processed query 83: Generated bitmaps.
# 2024-10-18 19:59:18,781 INFO:Processed query 84: Generated bitmaps.
# 2024-10-18 19:59:18,782 INFO:Processed query 85: Generated bitmaps.
# 2024-10-18 19:59:18,782 INFO:Processed query 86: Generated bitmaps.
# 2024-10-18 19:59:18,783 INFO:Processed query 87: Generated bitmaps.
# 2024-10-18 19:59:18,784 INFO:Processed query 88: Generated bitmaps.
# 2024-10-18 19:59:18,785 INFO:Processed query 89: Generated bitmaps.
# 2024-10-18 19:59:18,786 INFO:Processed query 90: Generated bitmaps.
# 2024-10-18 19:59:18,787 INFO:Processed query 91: Generated bitmaps.
# 2024-10-18 19:59:18,787 INFO:Processed query 92: Generated bitmaps.
# 2024-10-18 19:59:18,788 INFO:Processed query 93: Generated bitmaps.
# 2024-10-18 19:59:18,789 INFO:Processed query 94: Generated bitmaps.
# 2024-10-18 19:59:18,790 INFO:Processed query 95: Generated bitmaps.
# 2024-10-18 19:59:18,791 INFO:Processed query 96: Generated bitmaps.
# 2024-10-18 19:59:18,791 INFO:Processed query 97: Generated bitmaps.
# 2024-10-18 19:59:18,792 INFO:Processed query 98: Generated bitmaps.
# 2024-10-18 19:59:18,793 INFO:Processed query 99: Generated bitmaps.
# 2024-10-18 19:59:18,794 INFO:Processed query 100: Generated bitmaps.
# 2024-10-18 19:59:18,795 INFO:Processed query 101: Generated bitmaps.
# 2024-10-18 19:59:18,796 INFO:Processed query 102: Generated bitmaps.
# 2024-10-18 19:59:18,796 INFO:Processed query 103: Generated bitmaps.
# 2024-10-18 19:59:18,797 INFO:Processed query 104: Generated bitmaps.
# 2024-10-18 19:59:18,798 INFO:Processed query 105: Generated bitmaps.
# 2024-10-18 19:59:18,799 INFO:Processed query 106: Generated bitmaps.
# 2024-10-18 19:59:18,800 INFO:Processed query 107: Generated bitmaps.
# 2024-10-18 19:59:18,800 INFO:Processed query 108: Generated bitmaps.
# 2024-10-18 19:59:18,801 INFO:Processed query 109: Generated bitmaps.
# 2024-10-18 19:59:18,802 INFO:Processed query 110: Generated bitmaps.
# 2024-10-18 19:59:18,803 INFO:Processed query 111: Generated bitmaps.
# 2024-10-18 19:59:18,804 INFO:Processed query 112: Generated bitmaps.
# 2024-10-18 19:59:18,805 INFO:Processed query 113: Generated bitmaps.
# 2024-10-18 19:59:18,806 INFO:Processed query 114: Generated bitmaps.
# 2024-10-18 19:59:18,807 INFO:Processed query 115: Generated bitmaps.
# 2024-10-18 19:59:18,807 INFO:Processed query 116: Generated bitmaps.
# 2024-10-18 19:59:18,808 INFO:Processed query 117: Generated bitmaps.
# 2024-10-18 19:59:18,809 INFO:Processed query 118: Generated bitmaps.
# 2024-10-18 19:59:18,810 INFO:Processed query 119: Generated bitmaps.
# 2024-10-18 19:59:18,811 INFO:Processed query 120: Generated bitmaps.
# 2024-10-18 19:59:18,812 INFO:Processed query 121: Generated bitmaps.
# 2024-10-18 19:59:18,814 INFO:Processed query 122: Generated bitmaps.
# 2024-10-18 19:59:18,815 INFO:Processed query 123: Generated bitmaps.
# 2024-10-18 19:59:18,817 INFO:Processed query 124: Generated bitmaps.
# 2024-10-18 19:59:18,818 INFO:Processed query 125: Generated bitmaps.
# 2024-10-18 19:59:18,819 INFO:Processed query 126: Generated bitmaps.
# 2024-10-18 19:59:18,820 INFO:Processed query 127: Generated bitmaps.
# 2024-10-18 19:59:18,821 INFO:Processed query 128: Generated bitmaps.
# 2024-10-18 19:59:18,822 INFO:Processed query 129: Generated bitmaps.
# 2024-10-18 19:59:18,823 INFO:Processed query 130: Generated bitmaps.
# 2024-10-18 19:59:18,824 INFO:Processed query 131: Generated bitmaps.
# 2024-10-18 19:59:18,825 INFO:Processed query 132: Generated bitmaps.
# 2024-10-18 19:59:18,827 INFO:Processed query 133: Generated bitmaps.
# 2024-10-18 19:59:18,830 INFO:Processed query 134: Generated bitmaps.
# 2024-10-18 19:59:18,831 INFO:Processed query 135: Generated bitmaps.
# 2024-10-18 19:59:18,832 INFO:Processed query 136: Generated bitmaps.
# 2024-10-18 19:59:18,833 INFO:Processed query 137: Generated bitmaps.
# 2024-10-18 19:59:18,834 INFO:Processed query 138: Generated bitmaps.
# 2024-10-18 19:59:18,834 INFO:Processed query 139: Generated bitmaps.
# 2024-10-18 19:59:18,836 INFO:Processed query 140: Generated bitmaps.
# 2024-10-18 19:59:18,837 INFO:Processed query 141: Generated bitmaps.
# 2024-10-18 19:59:18,838 INFO:Processed query 142: Generated bitmaps.
# 2024-10-18 19:59:18,839 INFO:Processed query 143: Generated bitmaps.
# 2024-10-18 19:59:18,840 INFO:Processed query 144: Generated bitmaps.
# 2024-10-18 19:59:18,840 INFO:Processed query 145: Generated bitmaps.
# 2024-10-18 19:59:18,841 INFO:Processed query 146: Generated bitmaps.
# 2024-10-18 19:59:18,842 INFO:Processed query 147: Generated bitmaps.
# 2024-10-18 19:59:18,843 INFO:Processed query 148: Generated bitmaps.
# 2024-10-18 19:59:18,843 INFO:Processed query 149: Generated bitmaps.
# 2024-10-18 19:59:18,845 INFO:Processed query 150: Generated bitmaps.
# 2024-10-18 19:59:18,846 INFO:Processed query 151: Generated bitmaps.
# 2024-10-18 19:59:18,847 INFO:Processed query 152: Generated bitmaps.
# 2024-10-18 19:59:18,848 INFO:Processed query 153: Generated bitmaps.
# 2024-10-18 19:59:18,849 INFO:Processed query 154: Generated bitmaps.
# 2024-10-18 19:59:18,851 INFO:Processed query 155: Generated bitmaps.
# 2024-10-18 19:59:18,852 INFO:Processed query 156: Generated bitmaps.
# 2024-10-18 19:59:18,853 INFO:Processed query 157: Generated bitmaps.
# 2024-10-18 19:59:18,854 INFO:Processed query 158: Generated bitmaps.
# 2024-10-18 19:59:18,855 INFO:Processed query 159: Generated bitmaps.
# 2024-10-18 19:59:18,856 INFO:Processed query 160: Generated bitmaps.
# 2024-10-18 19:59:18,857 INFO:Processed query 161: Generated bitmaps.
# 2024-10-18 19:59:18,859 INFO:Processed query 162: Generated bitmaps.
# 2024-10-18 19:59:18,860 INFO:Processed query 163: Generated bitmaps.
# 2024-10-18 19:59:18,861 INFO:Processed query 164: Generated bitmaps.
# 2024-10-18 19:59:18,862 INFO:Processed query 165: Generated bitmaps.
# 2024-10-18 19:59:18,863 INFO:Processed query 166: Generated bitmaps.
# 2024-10-18 19:59:18,864 INFO:Processed query 167: Generated bitmaps.
# 2024-10-18 19:59:18,867 INFO:Processed query 168: Generated bitmaps.
# 2024-10-18 19:59:18,868 INFO:Processed query 169: Generated bitmaps.
# 2024-10-18 19:59:18,869 INFO:Processed query 170: Generated bitmaps.
# 2024-10-18 19:59:18,871 INFO:Processed query 171: Generated bitmaps.
# 2024-10-18 19:59:18,872 INFO:Processed query 172: Generated bitmaps.
# 2024-10-18 19:59:18,873 INFO:Processed query 173: Generated bitmaps.
# 2024-10-18 19:59:18,874 INFO:Processed query 174: Generated bitmaps.
# 2024-10-18 19:59:18,875 INFO:Processed query 175: Generated bitmaps.
# 2024-10-18 19:59:18,876 INFO:Processed query 176: Generated bitmaps.
# 2024-10-18 19:59:18,877 INFO:Processed query 177: Generated bitmaps.
# 2024-10-18 19:59:18,878 INFO:Processed query 178: Generated bitmaps.
# 2024-10-18 19:59:18,878 INFO:Processed query 179: Generated bitmaps.
# 2024-10-18 19:59:18,879 INFO:Processed query 180: Generated bitmaps.
# 2024-10-18 19:59:18,880 INFO:Processed query 181: Generated bitmaps.
# 2024-10-18 19:59:18,881 INFO:Processed query 182: Generated bitmaps.
# 2024-10-18 19:59:18,882 INFO:Processed query 183: Generated bitmaps.
# 2024-10-18 19:59:18,882 INFO:Processed query 184: Generated bitmaps.
# 2024-10-18 19:59:18,883 INFO:Processed query 185: Generated bitmaps.
# 2024-10-18 19:59:18,884 INFO:Processed query 186: Generated bitmaps.
# 2024-10-18 19:59:18,885 INFO:Processed query 187: Generated bitmaps.
# 2024-10-18 19:59:18,885 INFO:Processed query 188: Generated bitmaps.
# 2024-10-18 19:59:18,886 INFO:Processed query 189: Generated bitmaps.
# 2024-10-18 19:59:18,887 INFO:Processed query 190: Generated bitmaps.
# 2024-10-18 19:59:18,888 INFO:Processed query 191: Generated bitmaps.
# 2024-10-18 19:59:18,889 INFO:Processed query 192: Generated bitmaps.
# 2024-10-18 19:59:18,889 INFO:Processed query 193: Generated bitmaps.
# 2024-10-18 19:59:18,890 INFO:Processed query 194: Generated bitmaps.
# 2024-10-18 19:59:18,891 INFO:Processed query 195: Generated bitmaps.
# 2024-10-18 19:59:18,892 INFO:Processed query 196: Generated bitmaps.
# 2024-10-18 19:59:18,893 INFO:Processed query 197: Generated bitmaps.
# 2024-10-18 19:59:18,894 INFO:Processed query 198: Generated bitmaps.
# 2024-10-18 19:59:18,895 INFO:Processed query 199: Generated bitmaps.
# 2024-10-18 19:59:18,896 INFO:Processed query 200: Generated bitmaps.
# 2024-10-18 19:59:18,897 INFO:Processed query 201: Generated bitmaps.
# 2024-10-18 19:59:18,897 INFO:Processed query 202: Generated bitmaps.
# 2024-10-18 19:59:18,898 INFO:Processed query 203: Generated bitmaps.
# 2024-10-18 19:59:18,899 INFO:Processed query 204: Generated bitmaps.
# 2024-10-18 19:59:18,900 INFO:Processed query 205: Generated bitmaps.
# 2024-10-18 19:59:18,901 INFO:Processed query 206: Generated bitmaps.
# 2024-10-18 19:59:18,902 INFO:Processed query 207: Generated bitmaps.
# 2024-10-18 19:59:18,903 INFO:Processed query 208: Generated bitmaps.
# 2024-10-18 19:59:18,904 INFO:Processed query 209: Generated bitmaps.
# 2024-10-18 19:59:18,905 INFO:Processed query 210: Generated bitmaps.
# 2024-10-18 19:59:18,905 INFO:Processed query 211: Generated bitmaps.
# 2024-10-18 19:59:18,906 INFO:Processed query 212: Generated bitmaps.
# 2024-10-18 19:59:18,907 INFO:Processed query 213: Generated bitmaps.
# 2024-10-18 19:59:18,908 INFO:Processed query 214: Generated bitmaps.
# 2024-10-18 19:59:18,909 INFO:Processed query 215: Generated bitmaps.
# 2024-10-18 19:59:18,910 INFO:Processed query 216: Generated bitmaps.
# 2024-10-18 19:59:18,911 INFO:Processed query 217: Generated bitmaps.
# 2024-10-18 19:59:18,912 INFO:Processed query 218: Generated bitmaps.
# 2024-10-18 19:59:18,912 INFO:Processed query 219: Generated bitmaps.
# 2024-10-18 19:59:18,913 INFO:Processed query 220: Generated bitmaps.
# 2024-10-18 19:59:18,914 INFO:Processed query 221: Generated bitmaps.
# 2024-10-18 19:59:18,915 INFO:Processed query 222: Generated bitmaps.
# 2024-10-18 19:59:18,916 INFO:Processed query 223: Generated bitmaps.
# 2024-10-18 19:59:18,917 INFO:Processed query 224: Generated bitmaps.
# 2024-10-18 19:59:18,918 INFO:Processed query 225: Generated bitmaps.
# 2024-10-18 19:59:18,919 INFO:Processed query 226: Generated bitmaps.
# 2024-10-18 19:59:18,920 INFO:Processed query 227: Generated bitmaps.
# 2024-10-18 19:59:18,920 INFO:Processed query 228: Generated bitmaps.
# 2024-10-18 19:59:18,921 INFO:Processed query 229: Generated bitmaps.
# 2024-10-18 19:59:18,922 INFO:Processed query 230: Generated bitmaps.
# 2024-10-18 19:59:18,922 INFO:Processed query 231: Generated bitmaps.
# 2024-10-18 19:59:18,923 INFO:Processed query 232: Generated bitmaps.
# 2024-10-18 19:59:18,925 INFO:Processed query 233: Generated bitmaps.
# 2024-10-18 19:59:18,926 INFO:Processed query 234: Generated bitmaps.
# 2024-10-18 19:59:18,928 INFO:Processed query 235: Generated bitmaps.
# 2024-10-18 19:59:18,929 INFO:Processed query 236: Generated bitmaps.
# 2024-10-18 19:59:18,930 INFO:Processed query 237: Generated bitmaps.
# 2024-10-18 19:59:18,931 INFO:Processed query 238: Generated bitmaps.
# 2024-10-18 19:59:18,933 INFO:Processed query 239: Generated bitmaps.
# 2024-10-18 19:59:18,934 INFO:Processed query 240: Generated bitmaps.
# 2024-10-18 19:59:18,935 INFO:Processed query 241: Generated bitmaps.
# 2024-10-18 19:59:18,936 INFO:Processed query 242: Generated bitmaps.
# 2024-10-18 19:59:18,938 INFO:Processed query 243: Generated bitmaps.
# 2024-10-18 19:59:18,939 INFO:Processed query 244: Generated bitmaps.
# 2024-10-18 19:59:18,940 INFO:Processed query 245: Generated bitmaps.
# 2024-10-18 19:59:18,942 INFO:Processed query 246: Generated bitmaps.
# 2024-10-18 19:59:18,943 INFO:Processed query 247: Generated bitmaps.
# 2024-10-18 19:59:18,944 INFO:Processed query 248: Generated bitmaps.
# 2024-10-18 19:59:18,945 INFO:Processed query 249: Generated bitmaps.
# 2024-10-18 19:59:18,947 INFO:Processed query 250: Generated bitmaps.
# 2024-10-18 19:59:18,948 INFO:Processed query 251: Generated bitmaps.
# 2024-10-18 19:59:18,949 INFO:Processed query 252: Generated bitmaps.
# 2024-10-18 19:59:18,950 INFO:Processed query 253: Generated bitmaps.
# 2024-10-18 19:59:18,951 INFO:Processed query 254: Generated bitmaps.
# 2024-10-18 19:59:18,953 INFO:Processed query 255: Generated bitmaps.
# 2024-10-18 19:59:18,954 INFO:Processed query 256: Generated bitmaps.
# 2024-10-18 19:59:18,954 INFO:Processed query 257: Generated bitmaps.
# 2024-10-18 19:59:18,955 INFO:Processed query 258: Generated bitmaps.
# 2024-10-18 19:59:18,957 INFO:Processed query 259: Generated bitmaps.
# 2024-10-18 19:59:18,958 INFO:Processed query 260: Generated bitmaps.
# 2024-10-18 19:59:18,959 INFO:Processed query 261: Generated bitmaps.
# 2024-10-18 19:59:18,961 INFO:Processed query 262: Generated bitmaps.
# 2024-10-18 19:59:18,962 INFO:Processed query 263: Generated bitmaps.
# 2024-10-18 19:59:18,963 INFO:Processed query 264: Generated bitmaps.
# 2024-10-18 19:59:18,964 INFO:Processed query 265: Generated bitmaps.
# 2024-10-18 19:59:18,966 INFO:Processed query 266: Generated bitmaps.
# 2024-10-18 19:59:18,967 INFO:Processed query 267: Generated bitmaps.
# 2024-10-18 19:59:18,969 INFO:Processed query 268: Generated bitmaps.
# 2024-10-18 19:59:18,970 INFO:Processed query 269: Generated bitmaps.
# 2024-10-18 19:59:18,971 INFO:Processed query 270: Generated bitmaps.
# 2024-10-18 19:59:18,972 INFO:Processed query 271: Generated bitmaps.
# 2024-10-18 19:59:18,974 INFO:Processed query 272: Generated bitmaps.
# 2024-10-18 19:59:18,983 INFO:Processed query 273: Generated bitmaps.
# 2024-10-18 19:59:18,986 INFO:Processed query 274: Generated bitmaps.
# 2024-10-18 19:59:18,988 INFO:Processed query 275: Generated bitmaps.
# 2024-10-18 19:59:18,990 INFO:Processed query 276: Generated bitmaps.
# 2024-10-18 19:59:18,992 INFO:Processed query 277: Generated bitmaps.
# 2024-10-18 19:59:18,994 INFO:Processed query 278: Generated bitmaps.
# 2024-10-18 19:59:18,995 INFO:Processed query 279: Generated bitmaps.
# 2024-10-18 19:59:18,996 INFO:Processed query 280: Generated bitmaps.
# 2024-10-18 19:59:18,998 INFO:Processed query 281: Generated bitmaps.
# 2024-10-18 19:59:19,000 INFO:Processed query 282: Generated bitmaps.
# 2024-10-18 19:59:19,001 INFO:Processed query 283: Generated bitmaps.
# 2024-10-18 19:59:19,002 INFO:Processed query 284: Generated bitmaps.
# 2024-10-18 19:59:19,004 INFO:Processed query 285: Generated bitmaps.
# 2024-10-18 19:59:19,005 INFO:Processed query 286: Generated bitmaps.
# 2024-10-18 19:59:19,005 INFO:Processed query 287: Generated bitmaps.
# 2024-10-18 19:59:19,007 INFO:Processed query 288: Generated bitmaps.
# 2024-10-18 19:59:19,007 INFO:Processed query 289: Generated bitmaps.
# 2024-10-18 19:59:19,009 INFO:Processed query 290: Generated bitmaps.
# 2024-10-18 19:59:19,010 INFO:Processed query 291: Generated bitmaps.
# 2024-10-18 19:59:19,011 INFO:Processed query 292: Generated bitmaps.
# 2024-10-18 19:59:19,012 INFO:Processed query 293: Generated bitmaps.
# 2024-10-18 19:59:19,014 INFO:Processed query 294: Generated bitmaps.
# 2024-10-18 19:59:19,015 INFO:Processed query 295: Generated bitmaps.
# 2024-10-18 19:59:19,016 INFO:Processed query 296: Generated bitmaps.
# 2024-10-18 19:59:19,017 INFO:Processed query 297: Generated bitmaps.
# 2024-10-18 19:59:19,019 INFO:Processed query 298: Generated bitmaps.
# 2024-10-18 19:59:19,020 INFO:Processed query 299: Generated bitmaps.
# 2024-10-18 19:59:19,021 INFO:Processed query 300: Generated bitmaps.
# 2024-10-18 19:59:19,022 INFO:Processed query 301: Generated bitmaps.
# 2024-10-18 19:59:19,024 INFO:Processed query 302: Generated bitmaps.
# 2024-10-18 19:59:19,025 INFO:Processed query 303: Generated bitmaps.
# 2024-10-18 19:59:19,026 INFO:Processed query 304: Generated bitmaps.
# 2024-10-18 19:59:19,030 INFO:Processed query 305: Generated bitmaps.
# 2024-10-18 19:59:19,031 INFO:Processed query 306: Generated bitmaps.
# 2024-10-18 19:59:19,032 INFO:Processed query 307: Generated bitmaps.
# 2024-10-18 19:59:19,032 INFO:Processed query 308: Generated bitmaps.
# 2024-10-18 19:59:19,034 INFO:Processed query 309: Generated bitmaps.
# 2024-10-18 19:59:19,038 INFO:Processed query 310: Generated bitmaps.
# 2024-10-18 19:59:19,040 INFO:Processed query 311: Generated bitmaps.
# 2024-10-18 19:59:19,043 INFO:Processed query 312: Generated bitmaps.
# 2024-10-18 19:59:19,045 INFO:Processed query 313: Generated bitmaps.
# 2024-10-18 19:59:19,046 INFO:Processed query 314: Generated bitmaps.
# 2024-10-18 19:59:19,047 INFO:Processed query 315: Generated bitmaps.
# 2024-10-18 19:59:19,049 INFO:Processed query 316: Generated bitmaps.
# 2024-10-18 19:59:19,050 INFO:Processed query 317: Generated bitmaps.
# 2024-10-18 19:59:19,051 INFO:Processed query 318: Generated bitmaps.
# 2024-10-18 19:59:19,053 INFO:Processed query 319: Generated bitmaps.
# 2024-10-18 19:59:19,054 INFO:Processed query 320: Generated bitmaps.
# 2024-10-18 19:59:19,056 INFO:Processed query 321: Generated bitmaps.
# 2024-10-18 19:59:19,057 INFO:Processed query 322: Generated bitmaps.
# 2024-10-18 19:59:19,057 INFO:Processed query 323: Generated bitmaps.
# 2024-10-18 19:59:19,059 INFO:Processed query 324: Generated bitmaps.
# 2024-10-18 19:59:19,059 INFO:Processed query 325: Generated bitmaps.
# 2024-10-18 19:59:19,061 INFO:Processed query 326: Generated bitmaps.
# 2024-10-18 19:59:19,063 INFO:Processed query 327: Generated bitmaps.
# 2024-10-18 19:59:19,064 INFO:Processed query 328: Generated bitmaps.
# 2024-10-18 19:59:19,066 INFO:Processed query 329: Generated bitmaps.
# 2024-10-18 19:59:19,067 INFO:Processed query 330: Generated bitmaps.
# 2024-10-18 19:59:19,068 INFO:Processed query 331: Generated bitmaps.
# 2024-10-18 19:59:19,069 INFO:Processed query 332: Generated bitmaps.
# 2024-10-18 19:59:19,070 INFO:Processed query 333: Generated bitmaps.
# 2024-10-18 19:59:19,071 INFO:Processed query 334: Generated bitmaps.
# 2024-10-18 19:59:19,072 INFO:Processed query 335: Generated bitmaps.
# 2024-10-18 19:59:19,074 INFO:Processed query 336: Generated bitmaps.
# 2024-10-18 19:59:19,075 INFO:Processed query 337: Generated bitmaps.
# 2024-10-18 19:59:19,076 INFO:Processed query 338: Generated bitmaps.
# 2024-10-18 19:59:19,077 INFO:Processed query 339: Generated bitmaps.
# 2024-10-18 19:59:19,078 INFO:Processed query 340: Generated bitmaps.
# 2024-10-18 19:59:19,079 INFO:Processed query 341: Generated bitmaps.
# 2024-10-18 19:59:19,080 INFO:Processed query 342: Generated bitmaps.
# 2024-10-18 19:59:19,081 INFO:Processed query 343: Generated bitmaps.
# 2024-10-18 19:59:19,085 INFO:Processed query 344: Generated bitmaps.
# 2024-10-18 19:59:19,086 INFO:Processed query 345: Generated bitmaps.
# 2024-10-18 19:59:19,087 INFO:Processed query 346: Generated bitmaps.
# 2024-10-18 19:59:19,088 INFO:Processed query 347: Generated bitmaps.
# 2024-10-18 19:59:19,089 INFO:Processed query 348: Generated bitmaps.
# 2024-10-18 19:59:19,090 INFO:Processed query 349: Generated bitmaps.
# 2024-10-18 19:59:19,091 INFO:Processed query 350: Generated bitmaps.
# 2024-10-18 19:59:19,092 INFO:Processed query 351: Generated bitmaps.
# 2024-10-18 19:59:19,093 INFO:Processed query 352: Generated bitmaps.
# 2024-10-18 19:59:19,093 INFO:Processed query 353: Generated bitmaps.
# 2024-10-18 19:59:19,094 INFO:Processed query 354: Generated bitmaps.
# 2024-10-18 19:59:19,096 INFO:Processed query 355: Generated bitmaps.
# 2024-10-18 19:59:19,096 INFO:Processed query 356: Generated bitmaps.
# 2024-10-18 19:59:19,097 INFO:Processed query 357: Generated bitmaps.
# 2024-10-18 19:59:19,098 INFO:Processed query 358: Generated bitmaps.
# 2024-10-18 19:59:19,099 INFO:Processed query 359: Generated bitmaps.
# 2024-10-18 19:59:19,100 INFO:Processed query 360: Generated bitmaps.
# 2024-10-18 19:59:19,101 INFO:Processed query 361: Generated bitmaps.
# 2024-10-18 19:59:19,102 INFO:Processed query 362: Generated bitmaps.
# 2024-10-18 19:59:19,103 INFO:Processed query 363: Generated bitmaps.
# 2024-10-18 19:59:19,103 INFO:Processed query 364: Generated bitmaps.
# 2024-10-18 19:59:19,104 INFO:Processed query 365: Generated bitmaps.
# 2024-10-18 19:59:19,105 INFO:Processed query 366: Generated bitmaps.
# 2024-10-18 19:59:19,106 INFO:Processed query 367: Generated bitmaps.
# 2024-10-18 19:59:19,107 INFO:Processed query 368: Generated bitmaps.
# 2024-10-18 19:59:19,108 INFO:Processed query 369: Generated bitmaps.
# 2024-10-18 19:59:19,109 INFO:Processed query 370: Generated bitmaps.
# 2024-10-18 19:59:19,110 INFO:Processed query 371: Generated bitmaps.
# 2024-10-18 19:59:19,111 INFO:Processed query 372: Generated bitmaps.
# 2024-10-18 19:59:19,111 INFO:Processed query 373: Generated bitmaps.
# 2024-10-18 19:59:19,112 INFO:Processed query 374: Generated bitmaps.
# 2024-10-18 19:59:19,113 INFO:Processed query 375: Generated bitmaps.
# 2024-10-18 19:59:19,114 INFO:Processed query 376: Generated bitmaps.
# 2024-10-18 19:59:19,114 INFO:Processed query 377: Generated bitmaps.
# 2024-10-18 19:59:19,115 INFO:Processed query 378: Generated bitmaps.
# 2024-10-18 19:59:19,116 INFO:Processed query 379: Generated bitmaps.
# 2024-10-18 19:59:19,117 INFO:Processed query 380: Generated bitmaps.
# 2024-10-18 19:59:19,118 INFO:Processed query 381: Generated bitmaps.
# 2024-10-18 19:59:19,119 INFO:Processed query 382: Generated bitmaps.
# 2024-10-18 19:59:19,119 INFO:Processed query 383: Generated bitmaps.
# 2024-10-18 19:59:19,121 INFO:Processed query 384: Generated bitmaps.
# 2024-10-18 19:59:19,122 INFO:Processed query 385: Generated bitmaps.
# 2024-10-18 19:59:19,122 INFO:Processed query 386: Generated bitmaps.
# 2024-10-18 19:59:19,123 INFO:Processed query 387: Generated bitmaps.
# 2024-10-18 19:59:19,124 INFO:Processed query 388: Generated bitmaps.
# 2024-10-18 19:59:19,125 INFO:Processed query 389: Generated bitmaps.
# 2024-10-18 19:59:19,126 INFO:Processed query 390: Generated bitmaps.
# 2024-10-18 19:59:19,128 INFO:Processed query 391: Generated bitmaps.
# 2024-10-18 19:59:19,129 INFO:Processed query 392: Generated bitmaps.
# 2024-10-18 19:59:19,130 INFO:Processed query 393: Generated bitmaps.
# 2024-10-18 19:59:19,131 INFO:Processed query 394: Generated bitmaps.
# 2024-10-18 19:59:19,132 INFO:Processed query 395: Generated bitmaps.
# 2024-10-18 19:59:19,133 INFO:Processed query 396: Generated bitmaps.
# 2024-10-18 19:59:19,134 INFO:Processed query 397: Generated bitmaps.
# 2024-10-18 19:59:19,135 INFO:Processed query 398: Generated bitmaps.
# 2024-10-18 19:59:19,136 INFO:Processed query 399: Generated bitmaps.
# 2024-10-18 19:59:19,137 INFO:Processed query 400: Generated bitmaps.
# 2024-10-18 19:59:19,138 INFO:Processed query 401: Generated bitmaps.
# 2024-10-18 19:59:19,139 INFO:Processed query 402: Generated bitmaps.
# 2024-10-18 19:59:19,140 INFO:Processed query 403: Generated bitmaps.
# 2024-10-18 19:59:19,141 INFO:Processed query 404: Generated bitmaps.
# 2024-10-18 19:59:19,142 INFO:Processed query 405: Generated bitmaps.
# 2024-10-18 19:59:19,143 INFO:Processed query 406: Generated bitmaps.
# 2024-10-18 19:59:19,144 INFO:Processed query 407: Generated bitmaps.
# 2024-10-18 19:59:19,145 INFO:Processed query 408: Generated bitmaps.
# 2024-10-18 19:59:19,146 INFO:Processed query 409: Generated bitmaps.
# 2024-10-18 19:59:19,147 INFO:Processed query 410: Generated bitmaps.
# 2024-10-18 19:59:19,148 INFO:Processed query 411: Generated bitmaps.
# 2024-10-18 19:59:19,149 INFO:Processed query 412: Generated bitmaps.
# 2024-10-18 19:59:19,150 INFO:Processed query 413: Generated bitmaps.
# 2024-10-18 19:59:19,151 INFO:Processed query 414: Generated bitmaps.
# 2024-10-18 19:59:19,152 INFO:Processed query 415: Generated bitmaps.
# 2024-10-18 19:59:19,153 INFO:Processed query 416: Generated bitmaps.
# 2024-10-18 19:59:19,154 INFO:Processed query 417: Generated bitmaps.
# 2024-10-18 19:59:19,155 INFO:Processed query 418: Generated bitmaps.
# 2024-10-18 19:59:19,156 INFO:Processed query 419: Generated bitmaps.
# 2024-10-18 19:59:19,156 INFO:Processed query 420: Generated bitmaps.
# 2024-10-18 19:59:19,158 INFO:Processed query 421: Generated bitmaps.
# 2024-10-18 19:59:19,159 INFO:Processed query 422: Generated bitmaps.
# 2024-10-18 19:59:19,160 INFO:Processed query 423: Generated bitmaps.
# 2024-10-18 19:59:19,161 INFO:Processed query 424: Generated bitmaps.
# 2024-10-18 19:59:19,162 INFO:Processed query 425: Generated bitmaps.
# 2024-10-18 19:59:19,163 INFO:Processed query 426: Generated bitmaps.
# 2024-10-18 19:59:19,164 INFO:Processed query 427: Generated bitmaps.
# 2024-10-18 19:59:19,165 INFO:Processed query 428: Generated bitmaps.
# 2024-10-18 19:59:19,166 INFO:Processed query 429: Generated bitmaps.
# 2024-10-18 19:59:19,167 INFO:Processed query 430: Generated bitmaps.
# 2024-10-18 19:59:19,168 INFO:Processed query 431: Generated bitmaps.
# 2024-10-18 19:59:19,169 INFO:Processed query 432: Generated bitmaps.
# 2024-10-18 19:59:19,170 INFO:Processed query 433: Generated bitmaps.
# 2024-10-18 19:59:19,170 INFO:Processed query 434: Generated bitmaps.
# 2024-10-18 19:59:19,171 INFO:Processed query 435: Generated bitmaps.
# 2024-10-18 19:59:19,172 INFO:Processed query 436: Generated bitmaps.
# 2024-10-18 19:59:19,173 INFO:Processed query 437: Generated bitmaps.
# 2024-10-18 19:59:19,174 INFO:Processed query 438: Generated bitmaps.
# 2024-10-18 19:59:19,175 INFO:Processed query 439: Generated bitmaps.
# 2024-10-18 19:59:19,176 INFO:Processed query 440: Generated bitmaps.
# 2024-10-18 19:59:19,176 INFO:Processed query 441: Generated bitmaps.
# 2024-10-18 19:59:19,177 INFO:Processed query 442: Generated bitmaps.
# 2024-10-18 19:59:19,179 INFO:Processed query 443: Generated bitmaps.
# 2024-10-18 19:59:19,181 INFO:Processed query 444: Generated bitmaps.
# 2024-10-18 19:59:19,183 INFO:Processed query 445: Generated bitmaps.
# 2024-10-18 19:59:19,185 INFO:Processed query 446: Generated bitmaps.
# 2024-10-18 19:59:19,187 INFO:Processed query 447: Generated bitmaps.
# 2024-10-18 19:59:19,189 INFO:Processed query 448: Generated bitmaps.
# 2024-10-18 19:59:19,190 INFO:Processed query 449: Generated bitmaps.
# 2024-10-18 19:59:19,192 INFO:Processed query 450: Generated bitmaps.
# 2024-10-18 19:59:19,193 INFO:Processed query 451: Generated bitmaps.
# 2024-10-18 19:59:19,194 INFO:Processed query 452: Generated bitmaps.
# 2024-10-18 19:59:19,196 INFO:Processed query 453: Generated bitmaps.
# 2024-10-18 19:59:19,198 INFO:Processed query 454: Generated bitmaps.
# 2024-10-18 19:59:19,199 INFO:Processed query 455: Generated bitmaps.
# 2024-10-18 19:59:19,200 INFO:Processed query 456: Generated bitmaps.
# 2024-10-18 19:59:19,201 INFO:Processed query 457: Generated bitmaps.
# 2024-10-18 19:59:19,202 INFO:Processed query 458: Generated bitmaps.
# 2024-10-18 19:59:19,203 INFO:Processed query 459: Generated bitmaps.
# 2024-10-18 19:59:19,204 INFO:Processed query 460: Generated bitmaps.
# 2024-10-18 19:59:19,205 INFO:Processed query 461: Generated bitmaps.
# 2024-10-18 19:59:19,206 INFO:Processed query 462: Generated bitmaps.
# 2024-10-18 19:59:19,207 INFO:Processed query 463: Generated bitmaps.
# 2024-10-18 19:59:19,208 INFO:Processed query 464: Generated bitmaps.
# 2024-10-18 19:59:19,209 INFO:Processed query 465: Generated bitmaps.
# 2024-10-18 19:59:19,211 INFO:Processed query 466: Generated bitmaps.
# 2024-10-18 19:59:19,212 INFO:Processed query 467: Generated bitmaps.
# 2024-10-18 19:59:19,213 INFO:Processed query 468: Generated bitmaps.
# 2024-10-18 19:59:19,214 INFO:Processed query 469: Generated bitmaps.
# 2024-10-18 19:59:19,216 INFO:Processed query 470: Generated bitmaps.
# 2024-10-18 19:59:19,217 INFO:Processed query 471: Generated bitmaps.
# 2024-10-18 19:59:19,218 INFO:Processed query 472: Generated bitmaps.
# 2024-10-18 19:59:19,219 INFO:Processed query 473: Generated bitmaps.
# 2024-10-18 19:59:19,220 INFO:Processed query 474: Generated bitmaps.
# 2024-10-18 19:59:19,221 INFO:Processed query 475: Generated bitmaps.
# 2024-10-18 19:59:19,223 INFO:Processed query 476: Generated bitmaps.
# 2024-10-18 19:59:19,224 INFO:Processed query 477: Generated bitmaps.
# 2024-10-18 19:59:19,224 INFO:Processed query 478: Generated bitmaps.
# 2024-10-18 19:59:19,225 INFO:Processed query 479: Generated bitmaps.
# 2024-10-18 19:59:19,227 INFO:Processed query 480: Generated bitmaps.
# 2024-10-18 19:59:19,227 INFO:Processed query 481: Generated bitmaps.
# 2024-10-18 19:59:19,228 INFO:Processed query 482: Generated bitmaps.
# 2024-10-18 19:59:19,229 INFO:Processed query 483: Generated bitmaps.
# 2024-10-18 19:59:19,230 INFO:Processed query 484: Generated bitmaps.
# 2024-10-18 19:59:19,231 INFO:Processed query 485: Generated bitmaps.
# 2024-10-18 19:59:19,231 INFO:Processed query 486: Generated bitmaps.
# 2024-10-18 19:59:19,232 INFO:Processed query 487: Generated bitmaps.
# 2024-10-18 19:59:19,233 INFO:Processed query 488: Generated bitmaps.
# 2024-10-18 19:59:19,234 INFO:Processed query 489: Generated bitmaps.
# 2024-10-18 19:59:19,235 INFO:Processed query 490: Generated bitmaps.
# 2024-10-18 19:59:19,236 INFO:Processed query 491: Generated bitmaps.
# 2024-10-18 19:59:19,237 INFO:Processed query 492: Generated bitmaps.
# 2024-10-18 19:59:19,242 INFO:Processed query 493: Generated bitmaps.
# 2024-10-18 19:59:19,244 INFO:Processed query 494: Generated bitmaps.
# 2024-10-18 19:59:19,245 INFO:Processed query 495: Generated bitmaps.
# 2024-10-18 19:59:19,247 INFO:Processed query 496: Generated bitmaps.
# 2024-10-18 19:59:19,249 INFO:Processed query 497: Generated bitmaps.
# 2024-10-18 19:59:19,250 INFO:Processed query 498: Generated bitmaps.
# 2024-10-18 19:59:19,251 INFO:Processed query 499: Generated bitmaps.
# 2024-10-18 19:59:19,253 INFO:Processed query 500: Generated bitmaps.
# 2024-10-18 19:59:19,254 INFO:Processed query 501: Generated bitmaps.
# 2024-10-18 19:59:19,255 INFO:Processed query 502: Generated bitmaps.
# 2024-10-18 19:59:19,257 INFO:Processed query 503: Generated bitmaps.
# 2024-10-18 19:59:19,258 INFO:Processed query 504: Generated bitmaps.
# 2024-10-18 19:59:19,259 INFO:Processed query 505: Generated bitmaps.
# 2024-10-18 19:59:19,261 INFO:Processed query 506: Generated bitmaps.
# 2024-10-18 19:59:19,262 INFO:Processed query 507: Generated bitmaps.
# 2024-10-18 19:59:19,263 INFO:Processed query 508: Generated bitmaps.
# 2024-10-18 19:59:19,264 INFO:Processed query 509: Generated bitmaps.
# 2024-10-18 19:59:19,265 INFO:Processed query 510: Generated bitmaps.
# 2024-10-18 19:59:19,266 INFO:Processed query 511: Generated bitmaps.
# 2024-10-18 19:59:19,267 INFO:Processed query 512: Generated bitmaps.
# 2024-10-18 19:59:19,268 INFO:Processed query 513: Generated bitmaps.
# 2024-10-18 19:59:19,269 INFO:Processed query 514: Generated bitmaps.
# 2024-10-18 19:59:19,270 INFO:Processed query 515: Generated bitmaps.
# 2024-10-18 19:59:19,271 INFO:Processed query 516: Generated bitmaps.
# 2024-10-18 19:59:19,271 INFO:Processed query 517: Generated bitmaps.
# 2024-10-18 19:59:19,273 INFO:Processed query 518: Generated bitmaps.
# 2024-10-18 19:59:19,273 INFO:Processed query 519: Generated bitmaps.
# 2024-10-18 19:59:19,275 INFO:Processed query 520: Generated bitmaps.
# 2024-10-18 19:59:19,275 INFO:Processed query 521: Generated bitmaps.
# 2024-10-18 19:59:19,276 INFO:Processed query 522: Generated bitmaps.
# 2024-10-18 19:59:19,277 INFO:Processed query 523: Generated bitmaps.
# 2024-10-18 19:59:19,278 INFO:Processed query 524: Generated bitmaps.
# 2024-10-18 19:59:19,278 INFO:Processed query 525: Generated bitmaps.
# 2024-10-18 19:59:19,279 INFO:Processed query 526: Generated bitmaps.
# 2024-10-18 19:59:19,280 INFO:Processed query 527: Generated bitmaps.
# 2024-10-18 19:59:19,281 INFO:Processed query 528: Generated bitmaps.
# 2024-10-18 19:59:19,282 INFO:Processed query 529: Generated bitmaps.
# 2024-10-18 19:59:19,283 INFO:Processed query 530: Generated bitmaps.
# 2024-10-18 19:59:19,284 INFO:Processed query 531: Generated bitmaps.
# 2024-10-18 19:59:19,285 INFO:Processed query 532: Generated bitmaps.
# 2024-10-18 19:59:19,286 INFO:Processed query 533: Generated bitmaps.
# 2024-10-18 19:59:19,287 INFO:Processed query 534: Generated bitmaps.
# 2024-10-18 19:59:19,288 INFO:Processed query 535: Generated bitmaps.
# 2024-10-18 19:59:19,289 INFO:Processed query 536: Generated bitmaps.
# 2024-10-18 19:59:19,290 INFO:Processed query 537: Generated bitmaps.
# 2024-10-18 19:59:19,291 INFO:Processed query 538: Generated bitmaps.
# 2024-10-18 19:59:19,292 INFO:Processed query 539: Generated bitmaps.
# 2024-10-18 19:59:19,293 INFO:Processed query 540: Generated bitmaps.
# 2024-10-18 19:59:19,293 INFO:Processed query 541: Generated bitmaps.
# 2024-10-18 19:59:19,294 INFO:Processed query 542: Generated bitmaps.
# 2024-10-18 19:59:19,294 INFO:Processed query 543: Generated bitmaps.
# 2024-10-18 19:59:19,296 INFO:Processed query 544: Generated bitmaps.
# 2024-10-18 19:59:19,297 INFO:Processed query 545: Generated bitmaps.
# 2024-10-18 19:59:19,298 INFO:Processed query 546: Generated bitmaps.
# 2024-10-18 19:59:19,299 INFO:Processed query 547: Generated bitmaps.
# 2024-10-18 19:59:19,300 INFO:Processed query 548: Generated bitmaps.
# 2024-10-18 19:59:19,301 INFO:Processed query 549: Generated bitmaps.
# 2024-10-18 19:59:19,302 INFO:Processed query 550: Generated bitmaps.
# 2024-10-18 19:59:19,304 INFO:Processed query 551: Generated bitmaps.
# 2024-10-18 19:59:19,305 INFO:Processed query 552: Generated bitmaps.
# 2024-10-18 19:59:19,306 INFO:Processed query 553: Generated bitmaps.
# 2024-10-18 19:59:19,307 INFO:Processed query 554: Generated bitmaps.
# 2024-10-18 19:59:19,309 INFO:Processed query 555: Generated bitmaps.
# 2024-10-18 19:59:19,310 INFO:Processed query 556: Generated bitmaps.
# 2024-10-18 19:59:19,311 INFO:Processed query 557: Generated bitmaps.
# 2024-10-18 19:59:19,312 INFO:Processed query 558: Generated bitmaps.
# 2024-10-18 19:59:19,313 INFO:Processed query 559: Generated bitmaps.
# 2024-10-18 19:59:19,314 INFO:Processed query 560: Generated bitmaps.
# 2024-10-18 19:59:19,315 INFO:Processed query 561: Generated bitmaps.
# 2024-10-18 19:59:19,317 INFO:Processed query 562: Generated bitmaps.
# 2024-10-18 19:59:19,318 INFO:Processed query 563: Generated bitmaps.
# 2024-10-18 19:59:19,319 INFO:Processed query 564: Generated bitmaps.
# 2024-10-18 19:59:19,321 INFO:Processed query 565: Generated bitmaps.
# 2024-10-18 19:59:19,322 INFO:Processed query 566: Generated bitmaps.
# 2024-10-18 19:59:19,323 INFO:Processed query 567: Generated bitmaps.
# 2024-10-18 19:59:19,324 INFO:Processed query 568: Generated bitmaps.
# 2024-10-18 19:59:19,325 INFO:Processed query 569: Generated bitmaps.
# 2024-10-18 19:59:19,326 INFO:Processed query 570: Generated bitmaps.
# 2024-10-18 19:59:19,327 INFO:Processed query 571: Generated bitmaps.
# 2024-10-18 19:59:19,328 INFO:Processed query 572: Generated bitmaps.
# 2024-10-18 19:59:19,329 INFO:Processed query 573: Generated bitmaps.
# 2024-10-18 19:59:19,330 INFO:Processed query 574: Generated bitmaps.
# 2024-10-18 19:59:19,331 INFO:Processed query 575: Generated bitmaps.
# 2024-10-18 19:59:19,332 INFO:Processed query 576: Generated bitmaps.
# 2024-10-18 19:59:19,333 INFO:Processed query 577: Generated bitmaps.
# 2024-10-18 19:59:19,334 INFO:Processed query 578: Generated bitmaps.
# 2024-10-18 19:59:19,335 INFO:Processed query 579: Generated bitmaps.
# 2024-10-18 19:59:19,336 INFO:Processed query 580: Generated bitmaps.
# 2024-10-18 19:59:19,337 INFO:Processed query 581: Generated bitmaps.
# 2024-10-18 19:59:19,338 INFO:Processed query 582: Generated bitmaps.
# 2024-10-18 19:59:19,339 INFO:Processed query 583: Generated bitmaps.
# 2024-10-18 19:59:19,340 INFO:Processed query 584: Generated bitmaps.
# 2024-10-18 19:59:19,341 INFO:Processed query 585: Generated bitmaps.
# 2024-10-18 19:59:19,347 INFO:Processed query 586: Generated bitmaps.
# 2024-10-18 19:59:19,348 INFO:Processed query 587: Generated bitmaps.
# 2024-10-18 19:59:19,349 INFO:Processed query 588: Generated bitmaps.
# 2024-10-18 19:59:19,350 INFO:Processed query 589: Generated bitmaps.
# 2024-10-18 19:59:19,352 INFO:Processed query 590: Generated bitmaps.
# 2024-10-18 19:59:19,353 INFO:Processed query 591: Generated bitmaps.
# 2024-10-18 19:59:19,354 INFO:Processed query 592: Generated bitmaps.
# 2024-10-18 19:59:19,356 INFO:Processed query 593: Generated bitmaps.
# 2024-10-18 19:59:19,357 INFO:Processed query 594: Generated bitmaps.
# 2024-10-18 19:59:19,358 INFO:Processed query 595: Generated bitmaps.
# 2024-10-18 19:59:19,360 INFO:Processed query 596: Generated bitmaps.
# 2024-10-18 19:59:19,361 INFO:Processed query 597: Generated bitmaps.
# 2024-10-18 19:59:19,362 INFO:Processed query 598: Generated bitmaps.
# 2024-10-18 19:59:19,364 INFO:Processed query 599: Generated bitmaps.
# 2024-10-18 19:59:19,365 INFO:Processed query 600: Generated bitmaps.
# 2024-10-18 19:59:19,366 INFO:Processed query 601: Generated bitmaps.
# 2024-10-18 19:59:19,367 INFO:Processed query 602: Generated bitmaps.
# 2024-10-18 19:59:19,368 INFO:Processed query 603: Generated bitmaps.
# 2024-10-18 19:59:19,369 INFO:Processed query 604: Generated bitmaps.
# 2024-10-18 19:59:19,370 INFO:Processed query 605: Generated bitmaps.
# 2024-10-18 19:59:19,371 INFO:Processed query 606: Generated bitmaps.
# 2024-10-18 19:59:19,372 INFO:Processed query 607: Generated bitmaps.
# 2024-10-18 19:59:19,373 INFO:Processed query 608: Generated bitmaps.
# 2024-10-18 19:59:19,374 INFO:Processed query 609: Generated bitmaps.
# 2024-10-18 19:59:19,375 INFO:Processed query 610: Generated bitmaps.
# 2024-10-18 19:59:19,377 INFO:Processed query 611: Generated bitmaps.
# 2024-10-18 19:59:19,377 INFO:Processed query 612: Generated bitmaps.
# 2024-10-18 19:59:19,378 INFO:Processed query 613: Generated bitmaps.
# 2024-10-18 19:59:19,380 INFO:Processed query 614: Generated bitmaps.
# 2024-10-18 19:59:19,381 INFO:Processed query 615: Generated bitmaps.
# 2024-10-18 19:59:19,382 INFO:Processed query 616: Generated bitmaps.
# 2024-10-18 19:59:19,387 INFO:Processed query 617: Generated bitmaps.
# 2024-10-18 19:59:19,388 INFO:Processed query 618: Generated bitmaps.
# 2024-10-18 19:59:19,389 INFO:Processed query 619: Generated bitmaps.
# 2024-10-18 19:59:19,390 INFO:Processed query 620: Generated bitmaps.
# 2024-10-18 19:59:19,391 INFO:Processed query 621: Generated bitmaps.
# 2024-10-18 19:59:19,392 INFO:Processed query 622: Generated bitmaps.
# 2024-10-18 19:59:19,393 INFO:Processed query 623: Generated bitmaps.
# 2024-10-18 19:59:19,393 INFO:Processed query 624: Generated bitmaps.
# 2024-10-18 19:59:19,394 INFO:Processed query 625: Generated bitmaps.
# 2024-10-18 19:59:19,395 INFO:Processed query 626: Generated bitmaps.
# 2024-10-18 19:59:19,395 INFO:Processed query 627: Generated bitmaps.
# 2024-10-18 19:59:19,397 INFO:Processed query 628: Generated bitmaps.
# 2024-10-18 19:59:19,398 INFO:Processed query 629: Generated bitmaps.
# 2024-10-18 19:59:19,399 INFO:Processed query 630: Generated bitmaps.
# 2024-10-18 19:59:19,400 INFO:Processed query 631: Generated bitmaps.
# 2024-10-18 19:59:19,401 INFO:Processed query 632: Generated bitmaps.
# 2024-10-18 19:59:19,401 INFO:Processed query 633: Generated bitmaps.
# 2024-10-18 19:59:19,402 INFO:Processed query 634: Generated bitmaps.
# 2024-10-18 19:59:19,403 INFO:Processed query 635: Generated bitmaps.
# 2024-10-18 19:59:19,404 INFO:Processed query 636: Generated bitmaps.
# 2024-10-18 19:59:19,405 INFO:Processed query 637: Generated bitmaps.
# 2024-10-18 19:59:19,406 INFO:Processed query 638: Generated bitmaps.
# 2024-10-18 19:59:19,407 INFO:Processed query 639: Generated bitmaps.
# 2024-10-18 19:59:19,408 INFO:Processed query 640: Generated bitmaps.
# 2024-10-18 19:59:19,409 INFO:Processed query 641: Generated bitmaps.
# 2024-10-18 19:59:19,410 INFO:Processed query 642: Generated bitmaps.
# 2024-10-18 19:59:19,411 INFO:Processed query 643: Generated bitmaps.
# 2024-10-18 19:59:19,411 INFO:Processed query 644: Generated bitmaps.
# 2024-10-18 19:59:19,414 INFO:Processed query 645: Generated bitmaps.
# 2024-10-18 19:59:19,416 INFO:Processed query 646: Generated bitmaps.
# 2024-10-18 19:59:19,417 INFO:Processed query 647: Generated bitmaps.
# 2024-10-18 19:59:19,419 INFO:Processed query 648: Generated bitmaps.
# 2024-10-18 19:59:19,421 INFO:Processed query 649: Generated bitmaps.
# 2024-10-18 19:59:19,422 INFO:Processed query 650: Generated bitmaps.
# 2024-10-18 19:59:19,423 INFO:Processed query 651: Generated bitmaps.
# 2024-10-18 19:59:19,425 INFO:Processed query 652: Generated bitmaps.
# 2024-10-18 19:59:19,426 INFO:Processed query 653: Generated bitmaps.
# 2024-10-18 19:59:19,427 INFO:Processed query 654: Generated bitmaps.
# 2024-10-18 19:59:19,428 INFO:Processed query 655: Generated bitmaps.
# 2024-10-18 19:59:19,430 INFO:Processed query 656: Generated bitmaps.
# 2024-10-18 19:59:19,431 INFO:Processed query 657: Generated bitmaps.
# 2024-10-18 19:59:19,432 INFO:Processed query 658: Generated bitmaps.
# 2024-10-18 19:59:19,433 INFO:Processed query 659: Generated bitmaps.
# 2024-10-18 19:59:19,435 INFO:Processed query 660: Generated bitmaps.
# 2024-10-18 19:59:19,436 INFO:Processed query 661: Generated bitmaps.
# 2024-10-18 19:59:19,437 INFO:Processed query 662: Generated bitmaps.
# 2024-10-18 19:59:19,439 INFO:Processed query 663: Generated bitmaps.
# 2024-10-18 19:59:19,440 INFO:Processed query 664: Generated bitmaps.
# 2024-10-18 19:59:19,443 INFO:Processed query 665: Generated bitmaps.
# 2024-10-18 19:59:19,444 INFO:Processed query 666: Generated bitmaps.
# 2024-10-18 19:59:19,447 INFO:Processed query 667: Generated bitmaps.
# 2024-10-18 19:59:19,449 INFO:Processed query 668: Generated bitmaps.
# 2024-10-18 19:59:19,450 INFO:Processed query 669: Generated bitmaps.
# 2024-10-18 19:59:19,452 INFO:Processed query 670: Generated bitmaps.
# 2024-10-18 19:59:19,454 INFO:Processed query 671: Generated bitmaps.
# 2024-10-18 19:59:19,456 INFO:Processed query 672: Generated bitmaps.
# 2024-10-18 19:59:19,457 INFO:Processed query 673: Generated bitmaps.
# 2024-10-18 19:59:19,459 INFO:Processed query 674: Generated bitmaps.
# 2024-10-18 19:59:19,460 INFO:Processed query 675: Generated bitmaps.
# 2024-10-18 19:59:19,462 INFO:Processed query 676: Generated bitmaps.
# 2024-10-18 19:59:19,463 INFO:Processed query 677: Generated bitmaps.
# 2024-10-18 19:59:19,464 INFO:Processed query 678: Generated bitmaps.
# 2024-10-18 19:59:19,465 INFO:Processed query 679: Generated bitmaps.
# 2024-10-18 19:59:19,466 INFO:Processed query 680: Generated bitmaps.
# 2024-10-18 19:59:19,468 INFO:Processed query 681: Generated bitmaps.
# 2024-10-18 19:59:19,468 INFO:Processed query 682: Generated bitmaps.
# 2024-10-18 19:59:19,469 INFO:Processed query 683: Generated bitmaps.
# 2024-10-18 19:59:19,470 INFO:Processed query 684: Generated bitmaps.
# 2024-10-18 19:59:19,471 INFO:Processed query 685: Generated bitmaps.
# 2024-10-18 19:59:19,473 INFO:Processed query 686: Generated bitmaps.
# 2024-10-18 19:59:19,474 INFO:Processed query 687: Generated bitmaps.
# 2024-10-18 19:59:19,475 INFO:Processed query 688: Generated bitmaps.
# 2024-10-18 19:59:19,476 INFO:Processed query 689: Generated bitmaps.
# 2024-10-18 19:59:19,477 INFO:Processed query 690: Generated bitmaps.
# 2024-10-18 19:59:19,478 INFO:Processed query 691: Generated bitmaps.
# 2024-10-18 19:59:19,479 INFO:Processed query 692: Generated bitmaps.
# 2024-10-18 19:59:19,480 INFO:Processed query 693: Generated bitmaps.
# 2024-10-18 19:59:19,481 INFO:Processed query 694: Generated bitmaps.
# 2024-10-18 19:59:19,482 INFO:Processed query 695: Generated bitmaps.
# 2024-10-18 19:59:19,483 INFO:Processed query 696: Generated bitmaps.
# ...
# 2024-10-18 19:59:23,834 INFO:Processed query 4773: Generated bitmaps.
# 2024-10-18 19:59:23,835 INFO:Processed query 4774: Generated bitmaps.
# 2024-10-18 19:59:23,836 INFO:Processed query 4775: Generated bitmaps.
# 2024-10-18 19:59:23,837 INFO:Processed query 4776: Generated bitmaps.
# 2024-10-18 19:59:23,838 INFO:Processed query 4777: Generated bitmaps.
# 2024-10-18 19:59:23,838 INFO:Processed query 4778: Generated bitmaps.
# 2024-10-18 19:59:23,839 INFO:Processed query 4779: Generated bitmaps.
# 2024-10-18 19:59:23,840 INFO:Processed query 4780: Generated bitmaps.
# 2024-10-18 19:59:23,841 INFO:Processed query 4781: Generated bitmaps.
# 2024-10-18 19:59:23,841 INFO:Processed query 4782: Generated bitmaps.
# 2024-10-18 19:59:23,842 INFO:Processed query 4783: Generated bitmaps.
# 2024-10-18 19:59:23,843 INFO:Processed query 4784: Generated bitmaps.
# 2024-10-18 19:59:23,844 INFO:Processed query 4785: Generated bitmaps.
# 2024-10-18 19:59:23,844 INFO:Processed query 4786: Generated bitmaps.
# 2024-10-18 19:59:23,845 INFO:Processed query 4787: Generated bitmaps.
# 2024-10-18 19:59:23,846 INFO:Processed query 4788: Generated bitmaps.
# 2024-10-18 19:59:23,847 INFO:Processed query 4789: Generated bitmaps.
# 2024-10-18 19:59:23,848 INFO:Processed query 4790: Generated bitmaps.
# 2024-10-18 19:59:23,849 INFO:Processed query 4791: Generated bitmaps.
# 2024-10-18 19:59:23,849 INFO:Processed query 4792: Generated bitmaps.
# 2024-10-18 19:59:23,850 INFO:Processed query 4793: Generated bitmaps.
# 2024-10-18 19:59:23,851 INFO:Processed query 4794: Generated bitmaps.
# 2024-10-18 19:59:23,852 INFO:Processed query 4795: Generated bitmaps.
# 2024-10-18 19:59:23,852 INFO:Processed query 4796: Generated bitmaps.
# 2024-10-18 19:59:23,853 INFO:Processed query 4797: Generated bitmaps.
# 2024-10-18 19:59:23,854 INFO:Processed query 4798: Generated bitmaps.
# 2024-10-18 19:59:23,855 INFO:Processed query 4799: Generated bitmaps.
# 2024-10-18 19:59:23,855 INFO:Processed query 4800: Generated bitmaps.
# 2024-10-18 19:59:23,856 INFO:Processed query 4801: Generated bitmaps.
# 2024-10-18 19:59:23,857 INFO:Processed query 4802: Generated bitmaps.
# 2024-10-18 19:59:23,858 INFO:Processed query 4803: Generated bitmaps.
# 2024-10-18 19:59:23,858 INFO:Processed query 4804: Generated bitmaps.
# 2024-10-18 19:59:23,860 INFO:Processed query 4805: Generated bitmaps.
# 2024-10-18 19:59:23,862 INFO:Processed query 4806: Generated bitmaps.
# 2024-10-18 19:59:23,863 INFO:Processed query 4807: Generated bitmaps.
# 2024-10-18 19:59:23,865 INFO:Processed query 4808: Generated bitmaps.
# 2024-10-18 19:59:23,867 INFO:Processed query 4809: Generated bitmaps.
# 2024-10-18 19:59:23,869 INFO:Processed query 4810: Generated bitmaps.
# 2024-10-18 19:59:23,872 INFO:Processed query 4811: Generated bitmaps.
# 2024-10-18 19:59:23,874 INFO:Processed query 4812: Generated bitmaps.
# 2024-10-18 19:59:23,875 INFO:Processed query 4813: Generated bitmaps.
# 2024-10-18 19:59:23,877 INFO:Processed query 4814: Generated bitmaps.
# 2024-10-18 19:59:23,878 INFO:Processed query 4815: Generated bitmaps.
# 2024-10-18 19:59:23,879 INFO:Processed query 4816: Generated bitmaps.
# 2024-10-18 19:59:23,881 INFO:Processed query 4817: Generated bitmaps.
# 2024-10-18 19:59:23,882 INFO:Processed query 4818: Generated bitmaps.
# 2024-10-18 19:59:23,884 INFO:Processed query 4819: Generated bitmaps.
# 2024-10-18 19:59:23,885 INFO:Processed query 4820: Generated bitmaps.
# 2024-10-18 19:59:23,885 INFO:Processed query 4821: Generated bitmaps.
# 2024-10-18 19:59:23,887 INFO:Processed query 4822: Generated bitmaps.
# 2024-10-18 19:59:23,888 INFO:Processed query 4823: Generated bitmaps.
# 2024-10-18 19:59:23,889 INFO:Processed query 4824: Generated bitmaps.
# 2024-10-18 19:59:23,890 INFO:Processed query 4825: Generated bitmaps.
# 2024-10-18 19:59:23,891 INFO:Processed query 4826: Generated bitmaps.
# 2024-10-18 19:59:23,891 INFO:Processed query 4827: Generated bitmaps.
# 2024-10-18 19:59:23,893 INFO:Processed query 4828: Generated bitmaps.
# 2024-10-18 19:59:23,894 INFO:Processed query 4829: Generated bitmaps.
# 2024-10-18 19:59:23,894 INFO:Processed query 4830: Generated bitmaps.
# 2024-10-18 19:59:23,895 INFO:Processed query 4831: Generated bitmaps.
# 2024-10-18 19:59:23,896 INFO:Processed query 4832: Generated bitmaps.
# 2024-10-18 19:59:23,897 INFO:Processed query 4833: Generated bitmaps.
# 2024-10-18 19:59:23,898 INFO:Processed query 4834: Generated bitmaps.
# 2024-10-18 19:59:23,899 INFO:Processed query 4835: Generated bitmaps.
# 2024-10-18 19:59:23,900 INFO:Processed query 4836: Generated bitmaps.
# 2024-10-18 19:59:23,901 INFO:Processed query 4837: Generated bitmaps.
# 2024-10-18 19:59:23,902 INFO:Processed query 4838: Generated bitmaps.
# 2024-10-18 19:59:23,903 INFO:Processed query 4839: Generated bitmaps.
# 2024-10-18 19:59:23,904 INFO:Processed query 4840: Generated bitmaps.
# 2024-10-18 19:59:23,905 INFO:Processed query 4841: Generated bitmaps.
# 2024-10-18 19:59:23,906 INFO:Processed query 4842: Generated bitmaps.
# 2024-10-18 19:59:23,907 INFO:Processed query 4843: Generated bitmaps.
# 2024-10-18 19:59:23,908 INFO:Processed query 4844: Generated bitmaps.
# 2024-10-18 19:59:23,908 INFO:Processed query 4845: Generated bitmaps.
# 2024-10-18 19:59:23,909 INFO:Processed query 4846: Generated bitmaps.
# 2024-10-18 19:59:23,910 INFO:Processed query 4847: Generated bitmaps.
# 2024-10-18 19:59:23,911 INFO:Processed query 4848: Generated bitmaps.
# 2024-10-18 19:59:23,912 INFO:Processed query 4849: Generated bitmaps.
# 2024-10-18 19:59:23,912 INFO:Processed query 4850: Generated bitmaps.
# 2024-10-18 19:59:23,913 INFO:Processed query 4851: Generated bitmaps.
# 2024-10-18 19:59:23,914 INFO:Processed query 4852: Generated bitmaps.
# 2024-10-18 19:59:23,915 INFO:Processed query 4853: Generated bitmaps.
# 2024-10-18 19:59:23,916 INFO:Processed query 4854: Generated bitmaps.
# 2024-10-18 19:59:23,917 INFO:Processed query 4855: Generated bitmaps.
# 2024-10-18 19:59:23,917 INFO:Processed query 4856: Generated bitmaps.
# 2024-10-18 19:59:23,918 INFO:Processed query 4857: Generated bitmaps.
# 2024-10-18 19:59:23,919 INFO:Processed query 4858: Generated bitmaps.
# 2024-10-18 19:59:23,920 INFO:Processed query 4859: Generated bitmaps.
# 2024-10-18 19:59:23,921 INFO:Processed query 4860: Generated bitmaps.
# 2024-10-18 19:59:23,921 INFO:Processed query 4861: Generated bitmaps.
# 2024-10-18 19:59:23,922 INFO:Processed query 4862: Generated bitmaps.
# 2024-10-18 19:59:23,923 INFO:Processed query 4863: Generated bitmaps.
# 2024-10-18 19:59:23,924 INFO:Processed query 4864: Generated bitmaps.
# 2024-10-18 19:59:23,924 INFO:Processed query 4865: Generated bitmaps.
# 2024-10-18 19:59:23,925 INFO:Processed query 4866: Generated bitmaps.
# 2024-10-18 19:59:23,926 INFO:Processed query 4867: Generated bitmaps.
# 2024-10-18 19:59:23,927 INFO:Processed query 4868: Generated bitmaps.
# 2024-10-18 19:59:23,928 INFO:Processed query 4869: Generated bitmaps.
# 2024-10-18 19:59:23,928 INFO:Processed query 4870: Generated bitmaps.
# 2024-10-18 19:59:23,930 INFO:Processed query 4871: Generated bitmaps.
# 2024-10-18 19:59:23,930 INFO:Processed query 4872: Generated bitmaps.
# 2024-10-18 19:59:23,931 INFO:Processed query 4873: Generated bitmaps.
# 2024-10-18 19:59:23,932 INFO:Processed query 4874: Generated bitmaps.
# 2024-10-18 19:59:23,932 INFO:Processed query 4875: Generated bitmaps.
# 2024-10-18 19:59:23,933 INFO:Processed query 4876: Generated bitmaps.
# 2024-10-18 19:59:23,934 INFO:Processed query 4877: Generated bitmaps.
# 2024-10-18 19:59:23,935 INFO:Processed query 4878: Generated bitmaps.
# 2024-10-18 19:59:23,936 INFO:Processed query 4879: Generated bitmaps.
# 2024-10-18 19:59:23,937 INFO:Processed query 4880: Generated bitmaps.
# 2024-10-18 19:59:23,938 INFO:Processed query 4881: Generated bitmaps.
# 2024-10-18 19:59:23,938 INFO:Processed query 4882: Generated bitmaps.
# 2024-10-18 19:59:23,939 INFO:Processed query 4883: Generated bitmaps.
# 2024-10-18 19:59:23,940 INFO:Processed query 4884: Generated bitmaps.
# 2024-10-18 19:59:23,941 INFO:Processed query 4885: Generated bitmaps.
# 2024-10-18 19:59:23,941 INFO:Processed query 4886: Generated bitmaps.
# 2024-10-18 19:59:23,942 INFO:Processed query 4887: Generated bitmaps.
# 2024-10-18 19:59:23,943 INFO:Processed query 4888: Generated bitmaps.
# 2024-10-18 19:59:23,944 INFO:Processed query 4889: Generated bitmaps.
# 2024-10-18 19:59:23,945 INFO:Processed query 4890: Generated bitmaps.
# 2024-10-18 19:59:23,945 INFO:Processed query 4891: Generated bitmaps.
# 2024-10-18 19:59:23,946 INFO:Processed query 4892: Generated bitmaps.
# 2024-10-18 19:59:23,947 INFO:Processed query 4893: Generated bitmaps.
# 2024-10-18 19:59:23,948 INFO:Processed query 4894: Generated bitmaps.
# 2024-10-18 19:59:23,949 INFO:Processed query 4895: Generated bitmaps.
# 2024-10-18 19:59:23,950 INFO:Processed query 4896: Generated bitmaps.
# 2024-10-18 19:59:23,951 INFO:Processed query 4897: Generated bitmaps.
# 2024-10-18 19:59:23,952 INFO:Processed query 4898: Generated bitmaps.
# 2024-10-18 19:59:23,953 INFO:Processed query 4899: Generated bitmaps.
# 2024-10-18 19:59:23,954 INFO:Processed query 4900: Generated bitmaps.
# 2024-10-18 19:59:23,954 INFO:Processed query 4901: Generated bitmaps.
# 2024-10-18 19:59:23,955 INFO:Processed query 4902: Generated bitmaps.
# 2024-10-18 19:59:23,956 INFO:Processed query 4903: Generated bitmaps.
# 2024-10-18 19:59:23,957 INFO:Processed query 4904: Generated bitmaps.
# 2024-10-18 19:59:23,957 INFO:Processed query 4905: Generated bitmaps.
# 2024-10-18 19:59:23,958 INFO:Processed query 4906: Generated bitmaps.
# 2024-10-18 19:59:23,959 INFO:Processed query 4907: Generated bitmaps.
# 2024-10-18 19:59:23,960 INFO:Processed query 4908: Generated bitmaps.
# 2024-10-18 19:59:23,961 INFO:Processed query 4909: Generated bitmaps.
# 2024-10-18 19:59:23,962 INFO:Processed query 4910: Generated bitmaps.
# 2024-10-18 19:59:23,963 INFO:Processed query 4911: Generated bitmaps.
# 2024-10-18 19:59:23,964 INFO:Processed query 4912: Generated bitmaps.
# 2024-10-18 19:59:23,965 INFO:Processed query 4913: Generated bitmaps.
# 2024-10-18 19:59:23,966 INFO:Processed query 4914: Generated bitmaps.
# 2024-10-18 19:59:23,967 INFO:Processed query 4915: Generated bitmaps.
# 2024-10-18 19:59:23,967 INFO:Processed query 4916: Generated bitmaps.
# 2024-10-18 19:59:23,968 INFO:Processed query 4917: Generated bitmaps.
# 2024-10-18 19:59:23,969 INFO:Processed query 4918: Generated bitmaps.
# 2024-10-18 19:59:23,970 INFO:Processed query 4919: Generated bitmaps.
# 2024-10-18 19:59:23,971 INFO:Processed query 4920: Generated bitmaps.
# 2024-10-18 19:59:23,972 INFO:Processed query 4921: Generated bitmaps.
# 2024-10-18 19:59:23,973 INFO:Processed query 4922: Generated bitmaps.
# 2024-10-18 19:59:23,974 INFO:Processed query 4923: Generated bitmaps.
# 2024-10-18 19:59:23,975 INFO:Processed query 4924: Generated bitmaps.
# 2024-10-18 19:59:23,976 INFO:Processed query 4925: Generated bitmaps.
# 2024-10-18 19:59:23,976 INFO:Processed query 4926: Generated bitmaps.
# 2024-10-18 19:59:23,977 INFO:Processed query 4927: Generated bitmaps.
# 2024-10-18 19:59:23,978 INFO:Processed query 4928: Generated bitmaps.
# 2024-10-18 19:59:23,979 INFO:Processed query 4929: Generated bitmaps.
# 2024-10-18 19:59:23,980 INFO:Processed query 4930: Generated bitmaps.
# 2024-10-18 19:59:23,981 INFO:Processed query 4931: Generated bitmaps.
# 2024-10-18 19:59:23,982 INFO:Processed query 4932: Generated bitmaps.
# 2024-10-18 19:59:23,983 INFO:Processed query 4933: Generated bitmaps.
# 2024-10-18 19:59:23,984 INFO:Processed query 4934: Generated bitmaps.
# 2024-10-18 19:59:23,984 INFO:Processed query 4935: Generated bitmaps.
# 2024-10-18 19:59:23,985 INFO:Processed query 4936: Generated bitmaps.
# 2024-10-18 19:59:23,986 INFO:Processed query 4937: Generated bitmaps.
# 2024-10-18 19:59:23,987 INFO:Processed query 4938: Generated bitmaps.
# 2024-10-18 19:59:23,987 INFO:Processed query 4939: Generated bitmaps.
# 2024-10-18 19:59:23,988 INFO:Processed query 4940: Generated bitmaps.
# 2024-10-18 19:59:23,989 INFO:Processed query 4941: Generated bitmaps.
# 2024-10-18 19:59:23,990 INFO:Processed query 4942: Generated bitmaps.
# 2024-10-18 19:59:23,990 INFO:Processed query 4943: Generated bitmaps.
# 2024-10-18 19:59:23,991 INFO:Processed query 4944: Generated bitmaps.
# 2024-10-18 19:59:23,992 INFO:Processed query 4945: Generated bitmaps.
# 2024-10-18 19:59:23,993 INFO:Processed query 4946: Generated bitmaps.
# 2024-10-18 19:59:23,995 INFO:Processed query 4947: Generated bitmaps.
# 2024-10-18 19:59:23,996 INFO:Processed query 4948: Generated bitmaps.
# 2024-10-18 19:59:23,998 INFO:Processed query 4949: Generated bitmaps.
# 2024-10-18 19:59:24,000 INFO:Processed query 4950: Generated bitmaps.
# 2024-10-18 19:59:24,002 INFO:Processed query 4951: Generated bitmaps.
# 2024-10-18 19:59:24,003 INFO:Processed query 4952: Generated bitmaps.
# 2024-10-18 19:59:24,004 INFO:Processed query 4953: Generated bitmaps.
# 2024-10-18 19:59:24,006 INFO:Processed query 4954: Generated bitmaps.
# 2024-10-18 19:59:24,008 INFO:Processed query 4955: Generated bitmaps.
# 2024-10-18 19:59:24,009 INFO:Processed query 4956: Generated bitmaps.
# 2024-10-18 19:59:24,010 INFO:Processed query 4957: Generated bitmaps.
# 2024-10-18 19:59:24,012 INFO:Processed query 4958: Generated bitmaps.
# 2024-10-18 19:59:24,013 INFO:Processed query 4959: Generated bitmaps.
# 2024-10-18 19:59:24,016 INFO:Processed query 4960: Generated bitmaps.
# 2024-10-18 19:59:24,017 INFO:Processed query 4961: Generated bitmaps.
# 2024-10-18 19:59:24,018 INFO:Processed query 4962: Generated bitmaps.
# 2024-10-18 19:59:24,019 INFO:Processed query 4963: Generated bitmaps.
# 2024-10-18 19:59:24,021 INFO:Processed query 4964: Generated bitmaps.
# 2024-10-18 19:59:24,023 INFO:Processed query 4965: Generated bitmaps.
# 2024-10-18 19:59:24,025 INFO:Processed query 4966: Generated bitmaps.
# 2024-10-18 19:59:24,026 INFO:Processed query 4967: Generated bitmaps.
# 2024-10-18 19:59:24,027 INFO:Processed query 4968: Generated bitmaps.
# 2024-10-18 19:59:24,028 INFO:Processed query 4969: Generated bitmaps.
# 2024-10-18 19:59:24,029 INFO:Processed query 4970: Generated bitmaps.
# 2024-10-18 19:59:24,030 INFO:Processed query 4971: Generated bitmaps.
# 2024-10-18 19:59:24,031 INFO:Processed query 4972: Generated bitmaps.
# 2024-10-18 19:59:24,032 INFO:Processed query 4973: Generated bitmaps.
# 2024-10-18 19:59:24,033 INFO:Processed query 4974: Generated bitmaps.
# 2024-10-18 19:59:24,034 INFO:Processed query 4975: Generated bitmaps.
# 2024-10-18 19:59:24,035 INFO:Processed query 4976: Generated bitmaps.
# 2024-10-18 19:59:24,036 INFO:Processed query 4977: Generated bitmaps.
# 2024-10-18 19:59:24,037 INFO:Processed query 4978: Generated bitmaps.
# 2024-10-18 19:59:24,038 INFO:Processed query 4979: Generated bitmaps.
# 2024-10-18 19:59:24,039 INFO:Processed query 4980: Generated bitmaps.
# 2024-10-18 19:59:24,041 INFO:Processed query 4981: Generated bitmaps.
# 2024-10-18 19:59:24,042 INFO:Processed query 4982: Generated bitmaps.
# 2024-10-18 19:59:24,042 INFO:Processed query 4983: Generated bitmaps.
# 2024-10-18 19:59:24,043 INFO:Processed query 4984: Generated bitmaps.
# 2024-10-18 19:59:24,045 INFO:Processed query 4985: Generated bitmaps.
# 2024-10-18 19:59:24,045 INFO:Processed query 4986: Generated bitmaps.
# 2024-10-18 19:59:24,046 INFO:Processed query 4987: Generated bitmaps.
# 2024-10-18 19:59:24,047 INFO:Processed query 4988: Generated bitmaps.
# 2024-10-18 19:59:24,048 INFO:Processed query 4989: Generated bitmaps.
# 2024-10-18 19:59:24,048 INFO:Processed query 4990: Generated bitmaps.
# 2024-10-18 19:59:24,049 INFO:Processed query 4991: Generated bitmaps.
# 2024-10-18 19:59:24,050 INFO:Processed query 4992: Generated bitmaps.
# 2024-10-18 19:59:24,051 INFO:Processed query 4993: Generated bitmaps.
# 2024-10-18 19:59:24,052 INFO:Processed query 4994: Generated bitmaps.
# 2024-10-18 19:59:24,052 INFO:Processed query 4995: Generated bitmaps.
# 2024-10-18 19:59:24,053 INFO:Processed query 4996: Generated bitmaps.
# 2024-10-18 19:59:24,054 INFO:Processed query 4997: Generated bitmaps.
# 2024-10-18 19:59:24,055 INFO:Processed query 4998: Generated bitmaps.
# 2024-10-18 19:59:24,056 INFO:Processed query 4999: Generated bitmaps.
# 2024-10-18 19:59:24,056 INFO:Completed processing all synthetic workload queries.

# %%
table_samples[1].keys()
# Out:
# dict_keys(['title', 'movie_info'])

# %%
sum(table_samples[1]['movie_info'])
# Out:
# 828

# %%
bitmaps_df = pd.DataFrame(table_samples)
bitmaps_df.to_pickle('./data/imdb/workloads/synthetic_bimatps.pkl')

# %%
cur.close()
conn.close()

# %% [markdown]
# ## Sample
# ### Steps (There may be other easier methods)
# 1. generate 1000 sample points for each table
# 2. duplicate database schema from full db
#     > pg_dump imdb -s -O > imdb_schema.sql
# 3. create small base by in psql
#     > create database imdb_sample
# 4. create schema using imdb_schema.sql
# 5. load the sample data using pandas and sqlalchemy
# 6. query the small base to get sample bitmaps for each predicate

# %% [markdown]
# Step 1

# %%
## sampling extension
cmd = 'CREATE EXTENSION tsm_system_rows' # enable system rows sampling
cur.execute(cmd)
# Out:
# ---------------------------------------------------------------------------
# DuplicateObject                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 ## sampling extension
#       2 cmd = 'CREATE EXTENSION tsm_system_rows' # enable system rows sampling
# ----> 3 cur.execute(cmd)
#
# DuplicateObject: extension "tsm_system_rows" already exists

# %%
tables = list(imdb_schema.keys())
sample_data = {}
for table in tables:
    cur.execute("Select * FROM {} LIMIT 0".format(table))
    colnames = [desc[0] for desc in cur.description] # cur.description provides metadata about the result set, including column names and data types.

    ts = pd.DataFrame(columns = colnames)

    for num in range(1000):
        cmd = 'SELECT * FROM {} TABLESAMPLE SYSTEM_ROWS(1)'.format(table) # return 1 row per table
        cur.execute(cmd)
        samples = cur.fetchall()
        for i,row in enumerate(samples):
            ts.loc[num]=row
    
    sample_data[table] = ts
# Out:
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# ...
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row
# /tmp/ipykernel_1949574/552309919.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ts.loc[num]=row

# %%
sample_data['title']
# Out:
#           id                           title imdb_index  kind_id  \
# 0     932539                      You're On!       None        7
# 1     602982                         (#1.50)       None        7
# 2    1418446                      The Finale       None        7
# 3    1066816                         (#1.68)       None        7
# 4    1637227               1981 Liberty Bowl       None        3
# ..       ...                             ...        ...      ...
# 995  1873124  Esercito e marina a Bir Tobras       None        1
# 996   379939                          (#1.4)       None        7
# 997  1222418                    (1966-06-02)       None        7
# 998  1708517                   Backyard Fury       None        1
# 999  1348176                        The Oath       None        7
#
#     production_year imdb_id phonetic_code episode_of_id season_nr episode_nr  \
# 0              2012    None           Y65        932530      None       None
# 1              1988    None          None        599479         1         50
# 2              2009    None           F54       1418427         1          4
# 3              2006    None          None       1066746         1         68
# 4              1981    None         L1631          None      None       None
# ..              ...     ...           ...           ...       ...        ...
# 995            1912    None         E2623          None      None       None
# 996            2007    None          None        379934         1          4
# 997            1966    None          None       1222059      None       None
# 998            2008    None         B2631          None      None       None
# 999            1970    None            O3       1348156         1          8
#
#     series_years                            md5sum
# 0           None  a8966ecaddc04537483668396786e6ab
# 1           None  3a9d3d3b953b1e0307bb48b97f1c0c0e
# 2           None  3f49c17f0698ebc54367fd05c6c61941
# 3           None  eb23b6c6274ded914bd6603fe3d43a97
# 4           None  67bc4d25f1186ff177f8f9448686fe25
# ..           ...                               ...
# 995         None  4adf2f9b06e9916bba2a006dadc94954
# 996         None  966f98e1424f4a8d05442e950d5e96e0
# 997         None  b78f601e69b05330112f0973c7d9092e
# 998         None  dd17969cd068b60c2300fb5d1d53bf45
# 999         None  0085bd717731dec1725e55f9324523c8
#
# [1000 rows x 12 columns]

# %% [markdown]
# Step 5 (Do step 2-4 outside first)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:admin@localhost:5432/imdb_sample')

# %%
for k,v in sample_data.items():
    v['sid'] = list(range(1000))
    cmd = 'alter table {} add column sid integer'.format(k)
    cur.execute(cmd)
    v.to_sql(k,engine,if_exists='append',index=False) # insert the DataFrame `v` into the table `k` within the database `imdb_sample`

# %% [markdown]
# Step 6

# %%
query_file = pd.read_csv('data/imdb/workloads/synthetic.csv',sep='#',header=None)
query_file.columns = ['table','join','predicate','card']

# %%
query_file.head()
# Out:
#                                         table  \
# 0                                cast_info ci
# 1                       title t,movie_info mi
# 2                        title t,cast_info ci
# 3          title t,cast_info ci,movie_info mi
# 4  title t,cast_info ci,movie_info_idx mi_idx
#
#                                     join  \
# 0                                    NaN
# 1                       t.id=mi.movie_id
# 2                       t.id=ci.movie_id
# 3      t.id=ci.movie_id,t.id=mi.movie_id
# 4  t.id=ci.movie_id,t.id=mi_idx.movie_id
#
#                                            predicate      card
# 0                              ci.person_id,=,172968       838
# 1  t.kind_id,<,3,t.production_year,=,2008,mi.info...    297013
# 2                             ci.person_id,<,3194645  31427248
# 3  ci.person_id,=,1742124,ci.role_id,>,2,mi.info_...        12
# 4  t.kind_id,=,7,t.production_year,>,0,ci.role_id...    733244

# %%
conm = psycopg2.connect(database="imdb_sample", user="postgres", host="127.0.0.1",password="admin", port="5432")
conm.set_session(autocommit=True)
cur = conm.cursor()

# %%
table_samples = []
for i,row in query_file.iterrows():
    table_sample = {}
    preds = row['predicate'].split(',')
    for i in range(0,len(preds),3):
        left, op, right = preds[i:i+3]
        alias,col = left.split('.')
        table = alias2t[alias]
        pred_string = ''.join((col,op,right))
        # Constructs a SQL query to select the `sid` (sample ID) from the current `table` where the predicate holds true.
        q = 'select sid from {} where {}'.format(table, pred_string)
        cur.execute(q)
        sps = np.zeros(1000).astype('uint8')
        sids = cur.fetchall()
        sids = np.array(sids).squeeze()
        if sids.size>1: # at least 1 sample satisfies the predicate
            sps[sids] = 1
        if table in table_sample:
            table_sample[table] = table_sample[table] & sps
        else:
            table_sample[table] = sps
    table_samples.append(table_sample)

# %%
# table_samples
